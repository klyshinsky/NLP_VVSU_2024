# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
import pymorphy2
import re
import numpy as np
from tqdm import tqdm

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
with open("data/lenta2018.txt", encoding="utf-8") as news_file: # Файл с новостями.
    lenta_news = [n.split("-----\n")[1] for n in news_file.read().split("=====\n")[1:]]
    
with open("data/habr_10000.txt", encoding="utf-8") as news_file: # Файл с новостями.
    habr_news = [n for n in news_file.read().split("=====\n")[1:]]

# %%
imp_POS = ['ADJF', 'ADJS', 'NOUN', 'VERB', 'PRTF', 'PRTS', 'GRND', 'PREP']


def normalizePymorphy(text):
    tokens = re.findall('[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+', text)
    words = []
    for t in tokens:
        pv = morph.parse(t)
        if str(pv[0].tag.POS) in imp_POS:
            words.append(pv[0].normal_form)
    return words

# %%
lenta_news = [' '.join(normalizePymorphy(news)) for news in tqdm(lenta_news)]
habr_news = [' '.join(normalizePymorphy(news)) for news in tqdm(habr_news)]
# Out:
# 100%|███████████████████████████████████████| 1708/1708 [01:08<00:00, 25.03it/s]
# 100%|█████████████████████████████████████████| 708/708 [00:30<00:00, 23.06it/s]

# %%
tfv = TfidfVectorizer(token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                      ngram_range=(2, 3))

# %%
tf_lenta = tfv.fit_transform(lenta_news[:10])

# %%
tf_lenta
# Out:
# <10x2729 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2773 stored elements in Compressed Sparse Row format>

# %%
tfv.vocabulary_
# Out:
# {'испытанный украина': 791,
#  'украина первый': 2467,
#  'первый собственный': 1492,
#  'собственный крылатый': 2194,
#  'крылатый ракета': 918,
#  'ракета создать': 1904,
#  'создать кб': 2216,
#  'кб луч': 826,
#  'луч в': 965,
#  'в рамка': 216,
#  'рамка нептун': 1914,
#  'нептун на': 1217,
#  'на основа': 1101,
#  'основа российский': 1378,
#  'российский противокорабельный': 1985,
#  'противокорабельный ракета': 1826,
#  'ракета м': 1897,
#  'м комплекс': 979,
#  'комплекс х': 869,
#  'х у': 2560,
#  'у о': 2445,
#  'о писать': 1251,
#  'писать военный': 1516,
#  'военный блог': 341,
#  'блог который': 90,
#  'который вести': 896,
#  'вести сотрудник': 305,
#  'сотрудник московский': 2245,
#  'московский центр': 1052,
#  'центр анализ': 2576,
#  'анализ стратегия': 34,
#  'стратегия технология': 2320,
#  'технология напомнить': 2400,
#  'напомнить в': 1167,
#  'в советский': 239,
#  'советский период': 2200,
#  'период серийный': 1508,
#  'серийный производство': 2138,
#  'производство ракета': 1810,
#  'м х': 986,
#  'х планироваться': 2558,
#  'планироваться на': 1536,
#  'на харьковский': 1129,
#  'харьковский авиационный': 2566,
#  'авиационный завод': 4,
#  'завод нынешний': 669,
#  'нынешний хгапп': 1243,
#  'хгапп на': 2568,
#  'на украина': 1123,
#  'украина иметься': 2465,
#  'иметься полный': 749,
#  'полный комплект': 1644,
#  'комплект производственно-конструкторский': 871,
#  'производственно-конструкторский документация': 1804,
#  'документация на': 575,
#  'на этот': 1137,
#  'этот ракета': 2685,
#  'ракета вестись': 1893,
#  'вестись производство': 307,
#  'производство двигатель': 1806,
#  'двигатель отметить': 501,
#  'отметить эксперт': 1428,
#  'эксперт разработчик': 2675,
#  'разработчик противокорабельный': 1889,
#  'комплекс уран': 867,
#  'уран выступать': 2490,
#  'выступать головной': 403,
#  'головной предприятие': 456,
#  'предприятие ао': 1725,
#  'ао корпорация': 44,
#  'корпорация тактический': 886,
#  'тактический ракетный': 2360,
#  'ракетный вооружение': 1910,
#  'вооружение бывший': 353,
#  'бывший гнпц': 124,
#  'гнпц звезда-стрела': 431,
#  'звезда-стрела расположить': 701,
#  'расположить в': 1918,
#  'в подмосковный': 206,
#  'подмосковный королёв': 1596,
#  'королёв аналитик': 884,
#  'аналитик ссылаться': 36,
#  'ссылаться на': 2275,
#  'на иметься': 1086,
#  'иметься фото': 751,
#  'фото видеоматериал': 2538,
#  'видеоматериал тест': 319,
#  'тест полагать': 2390,
#  'полагать украина': 1632,
#  'украина провести': 2471,
#  'провести бросковый': 1795,
#  'бросковый испытание': 112,
#  'испытание макет': 787,
#  'макет ракета': 990,
#  'ракета у': 1906,
#  'у который': 2443,
#  'который быть': 894,
#  'быть отключить': 145,
#  'отключить турбореактивный': 1410,
#  'турбореактивный двигатель': 2429,
#  'двигатель отсутствовать': 503,
#  'отсутствовать система': 1448,
#  'система управление': 2161,
#  'управление по': 2488,
#  'по мнение': 1554,
#  'мнение эксперт': 1031,
#  'эксперт основной': 2673,
#  'основной проблема': 1386,
#  'проблема украина': 1793,
#  'украина при': 2469,
#  'при разработка': 1759,
#  'разработка нептун': 1885,
#  'нептун являться': 1221,
#  'являться создание': 2705,
#  'создание система': 2214,
#  'управление в': 2484,
#  'в первый': 204,
#  'первый очередь': 1490,
#  'очередь активный': 1454,
#  'активный радиолокационный': 18,
#  'радиолокационный головка': 1869,
#  'головка самонаведение': 454,
#  'самонаведение компетенция': 2070,
#  'компетенция в': 863,
#  'в у': 262,
#  'у украинский': 2449,
#  'украинский предприятие': 2474,
#  'предприятие отсутствовать': 1731,
#  'отсутствовать по': 1446,
#  'по данные': 1548,
#  'данные в': 492,
#  'в настоящий': 190,
#  'настоящий время': 1189,
#  'время разработка': 371,
#  'разработка подобный': 1887,
#  'подобный система': 1598,
#  'система в': 2157,
#  'в инициативный': 175,
#  'инициативный порядок': 759,
#  'порядок заниматься': 1670,
#  'заниматься киевский': 683,
#  'киевский частный': 830,
#  'частный ооо': 2592,
#  'ооо радионикс': 1345,
#  'радионикс новый': 1871,
#  'новый ракета': 1235,
#  'ракета должный': 1895,
#  'должный система': 583,
#  'система инерциально-спутниковый': 2159,
#  'инерциально-спутниковый коррекция': 755,
#  'коррекция с': 888,
#  'с использование': 2029,
#  'использование приёмник': 781,
#  'приёмник глонасс': 1791,
#  'глонасс для': 429,
#  'для быть': 545,
#  'быть доступный': 133,
#  'доступный аппаратура': 610,
#  'аппаратура американский': 46,
#  'американский производство': 30,
#  'производство материал': 1808,
#  'материал по': 1006,
#  'по тема': 1566,
#  'тема январярусский': 2386,
#  'январярусский смертьзакать': 2727,
#  'смертьзакать россия': 2182,
#  'россия возрождать': 1987,
#  'возрождать сверхзвуковой': 351,
#  'сверхзвуковой ракетоносец': 2082,
#  'ракетоносец тот': 1912,
#  'тот максимальный': 2416,
#  'максимальный дальность': 992,
#  'дальность стрельба': 490,
#  'стрельба ракета': 2322,
#  'ракета нептун': 1902,
#  'нептун составить': 1219,
#  'составить километр': 2243,
#  'километр комплекс': 834,
#  'комплекс планироваться': 865,
#  'планироваться к': 1534,
#  'к создание': 807,
#  'создание в': 2211,
#  'в вариант': 155,
#  'вариант наземный': 291,
#  'наземный корабельный': 1155,
#  'корабельный авиационный': 878,
#  'авиационный базирование': 2,
#  'базирование отмечать': 68,
#  'отмечать при': 1434,
#  'при первоочередной': 1757,
#  'первоочередной внимание': 1478,
#  'внимание быть': 335,
#  'быть наземный': 139,
#  'наземный вариант': 1153,
#  'вариант первый': 293,
#  'первый испытание': 1486,
#  'испытание собственный': 789,
#  'ракета украина': 1908,
#  'провести январь': 1797,
#  'январь ракета': 2723,
#  'ракета наземный': 1900,
#  'наземный базирование': 1151,
#  'отмечать секретарь': 1436,
#  'секретарь совет': 2101,
#  'совет национальный': 2198,
#  'национальный безопасность': 1199,
#  'безопасность оборона': 79,
#  'оборона снбо': 1291,
#  'снбо страна': 2186,
#  'страна александр': 2314,
#  'александр турчин': 24,
#  'турчин способный': 2431,
#  'способный наземный': 2261,
#  'наземный морской': 1157,
#  'морской цель': 1050,
#  'цель стать': 2572,
#  'стать один': 2296,
#  'один существенный': 1323,
#  'существенный аргумент': 2334,
#  'аргумент для': 50,
#  'для сдерживание': 559,
#  'сдерживание агрессор': 2094,
#  'испытанный украина первый': 792,
#  'украина первый собственный': 2468,
#  'первый собственный крылатый': 1493,
#  'собственный крылатый ракета': 2195,
#  'крылатый ракета создать': 919,
#  'ракета создать кб': 1905,
#  'создать кб луч': 2217,
#  'кб луч в': 827,
#  'луч в рамка': 966,
#  'в рамка нептун': 217,
#  'рамка нептун на': 1915,
#  'нептун на основа': 1218,
#  'на основа российский': 1102,
#  'основа российский противокорабельный': 1379,
#  'российский противокорабельный ракета': 1986,
#  'противокорабельный ракета м': 1827,
#  'ракета м комплекс': 1898,
#  'м комплекс х': 981,
#  'комплекс х у': 870,
#  'х у о': 2561,
#  'у о писать': 2446,
#  'о писать военный': 1252,
#  'писать военный блог': 1517,
#  'военный блог который': 342,
#  'блог который вести': 91,
#  'который вести сотрудник': 897,
#  'вести сотрудник московский': 306,
#  'сотрудник московский центр': 2246,
#  'московский центр анализ': 1053,
#  'центр анализ стратегия': 2577,
#  'анализ стратегия технология': 35,
#  'стратегия технология напомнить': 2321,
#  'технология напомнить в': 2401,
#  'напомнить в советский': 1168,
#  'в советский период': 240,
#  'советский период серийный': 2201,
#  'период серийный производство': 1509,
#  'серийный производство ракета': 2139,
#  'производство ракета м': 1811,
#  'ракета м х': 1899,
#  'м х планироваться': 987,
#  'х планироваться на': 2559,
#  'планироваться на харьковский': 1537,
#  'на харьковский авиационный': 1130,
#  'харьковский авиационный завод': 2567,
#  'авиационный завод нынешний': 5,
#  'завод нынешний хгапп': 670,
#  'нынешний хгапп на': 1244,
#  'хгапп на украина': 2569,
#  'на украина иметься': 1124,
#  'украина иметься полный': 2466,
#  'иметься полный комплект': 750,
#  'полный комплект производственно-конструкторский': 1645,
#  'комплект производственно-конструкторский документация': 872,
#  'производственно-конструкторский документация на': 1805,
#  'документация на этот': 576,
#  'на этот ракета': 1138,
#  'этот ракета вестись': 2686,
#  'ракета вестись производство': 1894,
#  'вестись производство двигатель': 308,
#  'производство двигатель отметить': 1807,
#  'двигатель отметить эксперт': 502,
#  'отметить эксперт разработчик': 1429,
#  'эксперт разработчик противокорабельный': 2676,
#  'разработчик противокорабельный ракета': 1890,
#  'м комплекс уран': 980,
#  'комплекс уран выступать': 868,
#  'уран выступать головной': 2491,
#  'выступать головной предприятие': 404,
#  'головной предприятие ао': 457,
#  'предприятие ао корпорация': 1726,
#  'ао корпорация тактический': 45,
#  'корпорация тактический ракетный': 887,
#  'тактический ракетный вооружение': 2361,
#  'ракетный вооружение бывший': 1911,
#  'вооружение бывший гнпц': 354,
#  'бывший гнпц звезда-стрела': 125,
#  'гнпц звезда-стрела расположить': 432,
#  'звезда-стрела расположить в': 702,
#  'расположить в подмосковный': 1920,
#  'в подмосковный королёв': 207,
#  'подмосковный королёв аналитик': 1597,
#  'королёв аналитик ссылаться': 885,
#  'аналитик ссылаться на': 37,
#  'ссылаться на иметься': 2276,
#  'на иметься фото': 1087,
#  'иметься фото видеоматериал': 752,
#  'фото видеоматериал тест': 2539,
#  'видеоматериал тест полагать': 320,
#  'тест полагать украина': 2391,
#  'полагать украина провести': 1633,
#  'украина провести бросковый': 2472,
#  'провести бросковый испытание': 1796,
#  'бросковый испытание макет': 113,
#  'испытание макет ракета': 788,
#  'макет ракета у': 991,
#  'ракета у который': 1907,
#  'у который быть': 2444,
#  'который быть отключить': 895,
#  'быть отключить турбореактивный': 146,
#  'отключить турбореактивный двигатель': 1411,
#  'турбореактивный двигатель отсутствовать': 2430,
#  'двигатель отсутствовать система': 504,
#  'отсутствовать система управление': 1449,
#  'система управление по': 2163,
#  'управление по мнение': 2489,
#  'по мнение эксперт': 1555,
#  'мнение эксперт основной': 1032,
#  'эксперт основной проблема': 2674,
#  'основной проблема украина': 1387,
#  'проблема украина при': 1794,
#  'украина при разработка': 2470,
#  'при разработка нептун': 1760,
#  'разработка нептун являться': 1886,
#  'нептун являться создание': 1222,
#  'являться создание система': 2706,
#  'создание система управление': 2215,
#  'система управление в': 2162,
#  'управление в первый': 2485,
#  'в первый очередь': 205,
#  'первый очередь активный': 1491,
#  'очередь активный радиолокационный': 1455,
#  'активный радиолокационный головка': 19,
#  'радиолокационный головка самонаведение': 1870,
#  'головка самонаведение компетенция': 455,
#  'самонаведение компетенция в': 2071,
#  'компетенция в у': 864,
#  'в у украинский': 263,
#  'у украинский предприятие': 2450,
#  'украинский предприятие отсутствовать': 2475,
#  'предприятие отсутствовать по': 1732,
#  'отсутствовать по данные': 1447,
#  'по данные в': 1549,
#  'данные в настоящий': 493,
#  'в настоящий время': 191,
#  'настоящий время разработка': 1190,
#  'время разработка подобный': 372,
#  'разработка подобный система': 1888,
#  'подобный система в': 1599,
#  'система в инициативный': 2158,
#  'в инициативный порядок': 176,
#  'инициативный порядок заниматься': 760,
#  'порядок заниматься киевский': 1671,
#  'заниматься киевский частный': 684,
#  'киевский частный ооо': 831,
#  'частный ооо радионикс': 2593,
#  'ооо радионикс новый': 1346,
#  'радионикс новый ракета': 1872,
#  'новый ракета должный': 1236,
#  'ракета должный система': 1896,
#  'должный система инерциально-спутниковый': 584,
#  'система инерциально-спутниковый коррекция': 2160,
#  'инерциально-спутниковый коррекция с': 756,
#  'коррекция с использование': 889,
#  'с использование приёмник': 2030,
#  'использование приёмник глонасс': 782,
#  'приёмник глонасс для': 1792,
#  'глонасс для быть': 430,
#  'для быть доступный': 546,
#  'быть доступный аппаратура': 134,
#  'доступный аппаратура американский': 611,
#  'аппаратура американский производство': 47,
#  'американский производство материал': 31,
#  'производство материал по': 1809,
#  'материал по тема': 1007,
#  'по тема январярусский': 1570,
#  'тема январярусский смертьзакать': 2387,
#  'январярусский смертьзакать россия': 2728,
#  'смертьзакать россия возрождать': 2183,
#  'россия возрождать сверхзвуковой': 1988,
#  'возрождать сверхзвуковой ракетоносец': 352,
#  'сверхзвуковой ракетоносец тот': 2083,
#  'ракетоносец тот максимальный': 1913,
#  'тот максимальный дальность': 2417,
#  'максимальный дальность стрельба': 993,
#  'дальность стрельба ракета': 491,
#  'стрельба ракета нептун': 2323,
#  'ракета нептун составить': 1903,
#  'нептун составить километр': 1220,
#  'составить километр комплекс': 2244,
#  'километр комплекс планироваться': 835,
#  'комплекс планироваться к': 866,
#  'планироваться к создание': 1535,
#  'к создание в': 808,
#  'создание в вариант': 2212,
#  'в вариант наземный': 156,
#  'вариант наземный корабельный': 292,
#  'наземный корабельный авиационный': 1156,
#  'корабельный авиационный базирование': 879,
#  'авиационный базирование отмечать': 3,
#  'базирование отмечать при': 69,
#  'отмечать при первоочередной': 1435,
#  'при первоочередной внимание': 1758,
#  'первоочередной внимание быть': 1479,
#  'внимание быть наземный': 336,
#  'быть наземный вариант': 140,
#  'наземный вариант первый': 1154,
#  'вариант первый испытание': 294,
#  'первый испытание собственный': 1487,
#  'испытание собственный крылатый': 790,
#  'крылатый ракета украина': 920,
#  'ракета украина провести': 1909,
#  'украина провести январь': 2473,
#  'провести январь ракета': 1799,
#  'январь ракета наземный': 2724,
#  'ракета наземный базирование': 1901,
#  'наземный базирование отмечать': 1152,
#  'базирование отмечать секретарь': 70,
#  'отмечать секретарь совет': 1437,
#  'секретарь совет национальный': 2102,
#  'совет национальный безопасность': 2199,
#  'национальный безопасность оборона': 1200,
#  'безопасность оборона снбо': 80,
#  'оборона снбо страна': 1292,
#  'снбо страна александр': 2187,
#  'страна александр турчин': 2315,
#  'александр турчин способный': 25,
#  'турчин способный наземный': 2432,
#  'способный наземный морской': 2262,
#  'наземный морской цель': 1158,
#  'морской цель стать': 1051,
#  'цель стать один': 2573,
#  'стать один существенный': 2297,
#  'один существенный аргумент': 1324,
#  'существенный аргумент для': 2335,
#  'аргумент для сдерживание': 51,
#  'для сдерживание агрессор': 560,
#  'пользователь выразить': 1650,
#  'выразить симпатия': 399,
#  'симпатия российский': 2155,
#  'российский гопник': 1981,
#  'гопник посетитель': 472,
#  'посетитель ресурс': 1672,
#  'ресурс оценить': 1963,
#  'оценить фотография': 1452,
#  'фотография с': 2544,
#  'с молодой': 2031,
#  'молодой человек': 1043,
#  'человек присесть': 2606,
#  'присесть лев-страж': 1785,
#  'лев-страж на': 937,
#  'на корточки': 1088,
#  'корточки на': 892,
#  'на опорный': 1095,
#  'опорный столб': 1353,
#  'столб ворота': 2306,
#  'ворота юзер': 355,
#  'юзер вывести': 2691,
#  'вывести снимка': 393,
#  'снимка в': 2188,
#  'в топ': 256,
#  'топ ресурс': 2410,
#  'ресурс разместить': 1965,
#  'разместить фото': 1881,
#  'фото пользователь': 2540,
#  'пользователь с': 1654,
#  'с ник': 2041,
#  'ник назвать': 1227,
#  'назвать композиция': 1149,
#  'композиция дмитрий': 873,
#  'дмитрий анатолий': 561,
#  'анатолий привратник': 40,
#  'привратник стража': 1763,
#  'стража славатар': 2312,
#  'славатар молиться': 2172,
#  'молиться удаться': 1041,
#  'удаться через': 2459,
#  'через адидассассин': 2612,
#  'адидассассин шутить': 14,
#  'шутить намекать': 2663,
#  'намекать на': 1161,
#  'на сюжет': 1121,
#  'сюжет игра': 2356,
#  'игра пользователь': 717,
#  'пользователь иронизировать': 1652,
#  'иронизировать рада': 777,
#  'рада выглядеть': 1867,
#  'выглядеть древний': 395,
#  'древний славянин': 614,
#  'славянин из': 2174,
#  'из город': 725,
#  'город славатар': 476,
#  'славатар материал': 2170,
#  'тема январь': 2384,
#  'январь пацан': 2721,
#  'пацан ребята': 1474,
#  'ребята русский': 1937,
#  'русский гопник': 2007,
#  'гопник покорить': 470,
#  'покорить интернет': 1630,
#  'интернет научить': 767,
#  'научить запад': 1192,
#  'запад на': 689,
#  'на повстречаться': 1105,
#  'повстречаться с': 1583,
#  'с гопник': 2019,
#  'гопник из': 464,
#  'из россия': 733,
#  'россия комментатор': 1989,
#  'комментатор отмечать': 859,
#  'отмечать крутой': 1432,
#  'крутой нрав': 916,
#  'нрав просить': 1241,
#  'просить от': 1822,
#  'от каждый': 1398,
#  'каждый раз': 813,
#  'раз пытаться': 1875,
#  'пытаться мимо': 1857,
#  'мимо в': 1021,
#  'в считать': 244,
#  'считать секунда': 2340,
#  'секунда становиться': 2122,
#  'становиться недееспособный': 2282,
#  'недееспособный пинать': 1209,
#  'пинать до': 1514,
#  'до смерть': 571,
#  'смерть кричать': 2180,
#  'кричать писать': 914,
#  'писать знаток': 1518,
#  'знаток культура': 709,
#  'культура обитатель': 927,
#  'обитатель российский': 1275,
#  'российский двор': 1983,
#  'двор продемонстрировать': 505,
#  'продемонстрировать знание': 1802,
#  'знание характерный': 707,
#  'характерный жаргон': 2564,
#  'жаргон некоторый': 627,
#  'некоторый материться': 1213,
#  'материться использовать': 1008,
#  'использовать латиница': 783,
#  'латиница культура': 933,
#  'культура русский': 929,
#  'гопник обрести': 466,
#  'обрести популярность': 1304,
#  'популярность в': 1662,
#  'в сеть': 235,
#  'сеть год': 2144,
#  'год западный': 443,
#  'западный молодёжь': 691,
#  'молодёжь показывать': 1046,
#  'показывать знание': 1628,
#  'знание русский': 705,
#  'русский мат': 2010,
#  'мат записывать': 1000,
#  'записывать ролик': 693,
#  'ролик в': 1973,
#  'в который': 182,
#  'который подражать': 904,
#  'подражать стиль': 1600,
#  'стиль гопник': 2302,
#  'гопник поведение': 468,
#  'поведение в': 1577,
#  'в частность': 269,
#  'частность демонстрировать': 2586,
#  'демонстрировать умение': 525,
#  'умение на': 2480,
#  'корточки в': 890,
#  'в январь': 278,
#  'январь один': 2719,
#  'один из': 1314,
#  'из самый': 735,
#  'самый популярный': 2076,
#  'популярный блогер': 1664,
#  'блогер показать': 92,
#  'показать владение': 1626,
#  'владение русский': 327,
#  'мат прокомментировать': 1002,
#  'прокомментировать такой': 1816,
#  'такой образ': 2358,
#  'образ новость': 1295,
#  'пользователь выразить симпатия': 1651,
#  'выразить симпатия российский': 400,
#  'симпатия российский гопник': 2156,
#  'российский гопник посетитель': 1982,
#  'гопник посетитель ресурс': 473,
#  'посетитель ресурс оценить': 1673,
#  'ресурс оценить фотография': 1964,
#  'оценить фотография с': 1453,
#  'фотография с молодой': 2545,
#  'с молодой человек': 2032,
#  'молодой человек присесть': 1044,
#  'человек присесть лев-страж': 2607,
#  'присесть лев-страж на': 1786,
#  'лев-страж на корточки': 938,
#  'на корточки на': 1090,
#  'корточки на опорный': 893,
#  'на опорный столб': 1096,
#  'опорный столб ворота': 1354,
#  'столб ворота юзер': 2307,
#  'ворота юзер вывести': 356,
#  'юзер вывести снимка': 2692,
#  'вывести снимка в': 394,
#  'снимка в топ': 2189,
#  'в топ ресурс': 257,
#  'топ ресурс разместить': 2411,
#  'ресурс разместить фото': 1966,
#  'разместить фото пользователь': 1882,
#  'фото пользователь с': 2541,
#  'пользователь с ник': 1655,
#  'с ник назвать': 2042,
#  'ник назвать композиция': 1228,
#  'назвать композиция дмитрий': 1150,
#  'композиция дмитрий анатолий': 874,
#  'дмитрий анатолий привратник': 562,
#  'анатолий привратник стража': 41,
#  'привратник стража славатар': 1764,
#  'стража славатар молиться': 2313,
#  'славатар молиться удаться': 2173,
#  'молиться удаться через': 1042,
#  'удаться через адидассассин': 2460,
#  'через адидассассин шутить': 2613,
#  'адидассассин шутить намекать': 15,
#  'шутить намекать на': 2664,
#  'намекать на сюжет': 1162,
#  'на сюжет игра': 1122,
#  'сюжет игра пользователь': 2357,
#  'игра пользователь иронизировать': 718,
#  'пользователь иронизировать рада': 1653,
#  'иронизировать рада выглядеть': 778,
#  'рада выглядеть древний': 1868,
#  'выглядеть древний славянин': 396,
#  'древний славянин из': 615,
#  'славянин из город': 2175,
#  'из город славатар': 726,
#  'город славатар материал': 477,
#  'славатар материал по': 2171,
#  'по тема январь': 1569,
#  'тема январь пацан': 2385,
#  'январь пацан ребята': 2722,
#  'пацан ребята русский': 1475,
#  'ребята русский гопник': 1938,
#  'русский гопник покорить': 2009,
#  'гопник покорить интернет': 471,
#  'покорить интернет научить': 1631,
#  'интернет научить запад': 768,
#  'научить запад на': 1193,
#  'запад на повстречаться': 690,
#  'на повстречаться с': 1106,
#  'повстречаться с гопник': 1584,
#  'с гопник из': 2020,
#  'гопник из россия': 465,
#  'из россия комментатор': 734,
#  'россия комментатор отмечать': 1990,
#  'комментатор отмечать крутой': 860,
#  'отмечать крутой нрав': 1433,
#  'крутой нрав просить': 917,
#  'нрав просить от': 1242,
#  'просить от каждый': 1823,
#  'от каждый раз': 1399,
#  'каждый раз пытаться': 814,
#  'раз пытаться мимо': 1876,
#  'пытаться мимо в': 1858,
#  'мимо в считать': 1022,
#  'в считать секунда': 245,
#  'считать секунда становиться': 2341,
#  'секунда становиться недееспособный': 2123,
#  'становиться недееспособный пинать': 2283,
#  'недееспособный пинать до': 1210,
#  'пинать до смерть': 1515,
#  'до смерть кричать': 572,
#  'смерть кричать писать': 2181,
#  'кричать писать знаток': 915,
#  'писать знаток культура': 1519,
#  'знаток культура обитатель': 710,
#  'культура обитатель российский': 928,
#  'обитатель российский двор': 1276,
#  'российский двор продемонстрировать': 1984,
#  'двор продемонстрировать знание': 506,
#  'продемонстрировать знание характерный': 1803,
#  'знание характерный жаргон': 708,
#  'характерный жаргон некоторый': 2565,
#  'жаргон некоторый материться': 628,
#  'некоторый материться использовать': 1214,
#  'материться использовать латиница': 1009,
#  'использовать латиница культура': 784,
#  'латиница культура русский': 934,
#  'культура русский гопник': 930,
#  'русский гопник обрести': 2008,
#  'гопник обрести популярность': 467,
#  'обрести популярность в': 1305,
#  'популярность в сеть': 1663,
#  'в сеть год': 236,
#  'сеть год западный': 2145,
#  'год западный молодёжь': 444,
#  'западный молодёжь показывать': 692,
#  'молодёжь показывать знание': 1047,
#  'показывать знание русский': 1629,
#  'знание русский мат': 706,
#  'русский мат записывать': 2011,
#  'мат записывать ролик': 1001,
#  'записывать ролик в': 694,
#  'ролик в который': 1974,
#  'в который подражать': 183,
#  'который подражать стиль': 905,
#  'подражать стиль гопник': 1601,
#  'стиль гопник поведение': 2303,
#  'гопник поведение в': 469,
#  'поведение в частность': 1578,
#  'в частность демонстрировать': 270,
#  'частность демонстрировать умение': 2587,
#  'демонстрировать умение на': 526,
#  'умение на корточки': 2481,
#  'на корточки в': 1089,
#  'корточки в январь': 891,
#  'в январь один': 280,
#  'январь один из': 2720,
#  'один из самый': 1318,
#  'из самый популярный': 736,
#  'самый популярный блогер': 2077,
#  'популярный блогер показать': 1665,
#  'блогер показать владение': 93,
#  'показать владение русский': 1627,
#  'владение русский мат': 328,
#  'русский мат прокомментировать': 2012,
#  'мат прокомментировать такой': 1003,
#  'прокомментировать такой образ': 1817,
#  'такой образ новость': 2359,
#  'в американский': 151,
#  'американский штат': 32,
#  'штат вирджиния': 2661,
#  'вирджиния пассажирский': 323,
#  'пассажирский поезд': 1470,
#  'поезд с': 1610,
#  'с член': 2055,
#  'член конгресс': 2629,
#  'конгресс сша': 876,
#  'сша от': 2346,
#  'от республиканский': 1402,
#  'республиканский партия': 1961,
#  'партия столкнуться': 1464,
#  'столкнуться с': 2310,
#  'с мусоровоз': 2037,
#  'мусоровоз о': 1072,
#  'о сообщать': 1257,
#  'сообщать в': 2220,
#  'в результат': 223,
#  'результат инцидент': 1947,
#  'инцидент погибнуть': 775,
#  'погибнуть один': 1585,
#  'один человек': 1325,
#  'человек один': 2602,
#  'один получить': 1319,
#  'получить серьёзный': 1648,
#  'серьёзный травма': 2142,
#  'травма находиться': 2422,
#  'находиться в': 1194,
#  'в грузовик': 167,
#  'грузовик среди': 484,
#  'среди политик': 2265,
#  'политик сопровождать': 1636,
#  'сопровождать персонал': 2239,
#  'персонал пострадать': 1510,
#  'пострадать ехать': 1684,
#  'ехать с': 625,
#  'с жена': 2025,
#  'жена сын': 631,
#  'сын в': 2352,
#  'в один': 196,
#  'из передний': 729,
#  'передний вагон': 1500,
#  'вагон сенатор': 283,
#  'сенатор от': 2126,
#  'от штат': 1408,
#  'штат аризона': 2659,
#  'аризона джефф': 58,
#  'джефф флейк': 539,
#  'флейк рассказать': 2536,
#  'рассказать журналист': 1921,
#  'журналист почувствовать': 649,
#  'почувствовать сильный': 1700,
#  'сильный удар': 2152,
#  'удар после': 2457,
#  'после побежать': 1680,
#  'побежать помощь': 1575,
#  'помощь раненый': 1660,
#  'раненый уточнить': 1916,
#  'уточнить после': 2508,
#  'после столкновение': 1682,
#  'столкновение первый': 2308,
#  'первый вагон': 1484,
#  'вагон состав': 285,
#  'состав сойти': 2241,
#  'сойти с': 2218,
#  'с рельс': 2047,
#  'рельс президент': 1957,
#  'президент сша': 1743,
#  'сша дональд': 2344,
#  'дональд трамп': 597,
#  'трамп информировать': 2424,
#  'информировать о': 773,
#  'о происшествие': 1253,
#  'происшествие декабрь': 1814,
#  'декабрь поезд': 517,
#  'поезд ехать': 1608,
#  'ехать из': 623,
#  'из портленд': 731,
#  'портленд в': 1668,
#  'в сиэтл': 237,
#  'сиэтл на': 2164,
#  'на скорость': 1117,
#  'скорость около': 2168,
#  'около километр': 1331,
#  'километр в': 832,
#  'в час': 267,
#  'час упасть': 2582,
#  'упасть с': 2482,
#  'с мост': 2035,
#  'мост на': 1054,
#  'на шоссе': 1135,
#  'шоссе в': 2653,
#  'результат пострадать': 1951,
#  'пострадать человек': 1690,
#  'человек падать': 2604,
#  'падать вагон': 1458,
#  'вагон повредить': 281,
#  'повредить легковой': 1581,
#  'легковой автомобиль': 941,
#  'автомобиль грузовик': 8,
#  'грузовик декабрь': 482,
#  'декабрь на': 513,
#  'на юг': 1139,
#  'юг франция': 2687,
#  'франция скоростной': 2550,
#  'скоростной электричка': 2166,
#  'электричка протаранить': 2677,
#  'протаранить школьный': 1824,
#  'школьный автобус': 2649,
#  'автобус пересекать': 6,
#  'пересекать железнодорожный': 1506,
#  'железнодорожный переезд': 629,
#  'переезд от': 1502,
#  'от сильный': 1404,
#  'удар перевозить': 2455,
#  'перевозить школьник': 1494,
#  'школьник машина': 2645,
#  'машина разорвать': 1010,
#  'разорвать на': 1883,
#  'на часть': 1133,
#  'часть погибнуть': 2594,
#  'погибнуть ребёнок': 1587,
#  'в американский штат': 152,
#  'американский штат вирджиния': 33,
#  'штат вирджиния пассажирский': 2662,
#  'вирджиния пассажирский поезд': 324,
#  'пассажирский поезд с': 1471,
#  'поезд с член': 1611,
#  'с член конгресс': 2056,
#  'член конгресс сша': 2630,
#  'конгресс сша от': 877,
#  'сша от республиканский': 2347,
#  'от республиканский партия': 1403,
#  'республиканский партия столкнуться': 1962,
#  'партия столкнуться с': 1465,
#  'столкнуться с мусоровоз': 2311,
#  'с мусоровоз о': 2038,
#  'мусоровоз о сообщать': 1073,
#  'о сообщать в': 1258,
#  'сообщать в результат': 2221,
#  'в результат инцидент': 224,
#  'результат инцидент погибнуть': 1948,
#  'инцидент погибнуть один': 776,
#  'погибнуть один человек': 1586,
#  'один человек один': 1326,
#  'человек один получить': 2603,
#  'один получить серьёзный': 1320,
#  'получить серьёзный травма': 1649,
#  'серьёзный травма находиться': 2143,
#  'травма находиться в': 2423,
#  'находиться в грузовик': 1195,
#  'в грузовик среди': 168,
#  'грузовик среди политик': 485,
#  'среди политик сопровождать': 2266,
#  'политик сопровождать персонал': 1637,
#  'сопровождать персонал пострадать': 2240,
#  'персонал пострадать ехать': 1511,
#  'пострадать ехать с': 1685,
#  'ехать с жена': 626,
#  'с жена сын': 2026,
#  'жена сын в': 632,
#  'сын в один': 2353,
#  'в один из': 197,
#  'один из передний': 1317,
#  'из передний вагон': 730,
#  'передний вагон сенатор': 1501,
#  'вагон сенатор от': 284,
#  'сенатор от штат': 2127,
#  'от штат аризона': 1409,
#  'штат аризона джефф': 2660,
#  'аризона джефф флейк': 59,
#  'джефф флейк рассказать': 540,
#  'флейк рассказать журналист': 2537,
#  'рассказать журналист почувствовать': 1922,
#  'журналист почувствовать сильный': 650,
#  'почувствовать сильный удар': 1701,
#  'сильный удар после': 2154,
#  'удар после побежать': 2458,
#  'после побежать помощь': 1681,
#  'побежать помощь раненый': 1576,
#  'помощь раненый уточнить': 1661,
#  'раненый уточнить после': 1917,
#  'уточнить после столкновение': 2509,
#  'после столкновение первый': 1683,
#  'столкновение первый вагон': 2309,
#  'первый вагон состав': 1485,
#  'вагон состав сойти': 286,
#  'состав сойти с': 2242,
#  'сойти с рельс': 2219,
#  'с рельс президент': 2048,
#  'рельс президент сша': 1958,
#  'президент сша дональд': 1744,
#  'сша дональд трамп': 2345,
#  'дональд трамп информировать': 598,
#  'трамп информировать о': 2425,
#  'информировать о происшествие': 774,
#  'о происшествие декабрь': 1254,
#  'происшествие декабрь поезд': 1815,
#  'декабрь поезд ехать': 518,
#  'поезд ехать из': 1609,
#  'ехать из портленд': 624,
#  'из портленд в': 732,
#  'портленд в сиэтл': 1669,
#  'в сиэтл на': 238,
#  'сиэтл на скорость': 2165,
#  'на скорость около': 1118,
#  'скорость около километр': 2169,
#  'около километр в': 1332,
#  'километр в час': 833,
#  'в час упасть': 268,
#  'час упасть с': 2583,
#  'упасть с мост': 2483,
#  'с мост на': 2036,
#  'мост на шоссе': 1055,
#  'на шоссе в': 1136,
#  'шоссе в результат': 2654,
#  'в результат пострадать': 225,
#  'результат пострадать человек': 1952,
#  'пострадать человек падать': 1691,
#  'человек падать вагон': 2605,
#  'падать вагон повредить': 1459,
#  'вагон повредить легковой': 282,
#  'повредить легковой автомобиль': 1582,
#  'легковой автомобиль грузовик': 942,
#  'автомобиль грузовик декабрь': 9,
#  'грузовик декабрь на': 483,
#  'декабрь на юг': 514,
#  'на юг франция': 1140,
#  'юг франция скоростной': 2688,
#  'франция скоростной электричка': 2551,
#  'скоростной электричка протаранить': 2167,
#  'электричка протаранить школьный': 2678,
#  'протаранить школьный автобус': 1825,
#  'школьный автобус пересекать': 2650,
#  'автобус пересекать железнодорожный': 7,
#  'пересекать железнодорожный переезд': 1507,
#  'железнодорожный переезд от': 630,
#  'переезд от сильный': 1503,
#  'от сильный удар': 1405,
#  'сильный удар перевозить': 2153,
#  'удар перевозить школьник': 2456,
#  'перевозить школьник машина': 1495,
#  'школьник машина разорвать': 2646,
#  'машина разорвать на': 1011,
#  'разорвать на часть': 1884,
#  'на часть погибнуть': 1134,
#  'часть погибнуть ребёнок': 2595,
#  'в франция': 264,
#  'франция открыться': 2548,
#  'открыться первый': 1416,
#  'первый бордель': 1480,
#  'бордель который': 102,
#  'который сдавать': 910,
#  'сдавать напрокат': 2092,
#  'напрокат секс-кукла': 1171,
#  'секс-кукла о': 2115,
#  'сообщать издание': 2222,
#  'издание клиент': 743,
#  'клиент заведение': 840,
#  ...}

# %%
# for news in tf_lenta:
#     print(sorted(news[0][:].todense()[0][0])[-5:])
    
    
freqwords = []
for i in tqdm(range(10)):

    tfs = [(word, tf_lenta[i, index]) for word, index in tfv.vocabulary_.items()
         if tf_lenta[i, index] != 0]
    fw = [w for w, f in sorted(tfs, key = lambda x: x[1], reverse = True)[:5]]
    freqwords.append(fw)
# Out:
# 100%|███████████████████████████████████████████| 10/10 [00:00<00:00, 25.16it/s]

# %%
freqwords
# Out:
# [['ракета м',
#   'собственный крылатый',
#   'крылатый ракета',
#   'противокорабельный ракета',
#   'м комплекс'],
#  ['на корточки',
#   'русский гопник',
#   'русский мат',
#   'пользователь выразить',
#   'выразить симпатия'],
#  ['в результат',
#   'сильный удар',
#   'в американский',
#   'американский штат',
#   'штат вирджиния'],
#  ['в франция',
#   'евро рубль',
#   'франция открыться',
#   'открыться первый',
#   'первый бордель'],
#  ['процент россиянин',
#   'данный показатель',
#   'процент избиратель',
#   'на выборы',
#   'выборы президент'],
#  ['сотрудник фсб',
#   'фсб задержать',
#   'задержать звезда',
#   'звезда телесериал',
#   'телесериал детектив'],
#  ['на ближний',
#   'ближний восток',
#   'в регион',
#   'совместный предприятие',
#   'клиентский сервис'],
#  ['причина исчезновение',
#   'исчезновение рыболовецкий',
#   'рыболовецкий судный',
#   'судный восток',
#   'восток с'],
#  ['в сексуальный',
#   'сексуальный домогательство',
#   'в сексуальный домогательство',
#   'в сша',
#   'с оральный'],
#  ['американский зоозащитный',
#   'зоозащитный организация',
#   'организация человек',
#   'человек за',
#   'за этичный']]

# %% [markdown]
# Из теории вероятности используется несколько формул для расчета степени неслучайности для словосочетий.
#
# $$MI(x, y)=log(\frac{f(x,y)*N}{f(x)*f(y)}),$$
# где $f(x)$ и $f(y)$ - частоты встречаемости слов $x$ и $y$, а $f(x,y)$ - частота встречаемости фразы $x y$.
#
# Для данной метрики берутся слова с самым большими значениями. Однако, так как нас интересует скорее ранжирование слов, чем абсолютные значения метрики, на практике удобнее использовать редуцированную формулу.
#
# $$PMI(x, y)=\frac{f(x,y)}{f(x)*f(y)}$$
#
# Еще одна формула:
#
# $$t-score(x, y)=\frac{f(x,y)-\frac{f(x)*f(y)}{N}}{\sqrt{f(x,y)}},$$
# где N - количество слов в коллекции.
#
# О различиях между результатами можно прочитать [здесь](https://cyberleninka.ru/article/n/ot-kollokatsiy-k-konstruktsiyam/viewer) (можно начинать со второго раздела) или [здесь](https://www.researchgate.net/publication/340371729_K_voprosu_o_shodstve_mer_associacii_primenitelno_k_zadace_avtomaticeskogo_izvlecenia_glagolnyh_kollokacij).
#
# Еще можно посмотреть информацию о [c-value](https://www.researchgate.net/publication/220387502_Automatic_Recognition_of_Multi-word_Terms_The_C-value_NC-value_Method).
#
# Давайте посчитаем значения этих

# %%
cntv1 = CountVectorizer(token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                        ngram_range=(1, 1))
cntv2 = CountVectorizer(token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                        ngram_range=(2, 2))

# %%
cnt_lenta_1 = cntv1.fit_transform(['\n'.join(lenta_news)])
cnt_lenta_2 = cntv2.fit_transform(['\n'.join(lenta_news)])

# %%
def calc_MI_tscore(cnt_lenta_1, cnt_lenta_2, cntv1, cntv2, thr):
    mis = {}
    t_scores = {}
    corp_len = cnt_lenta_1.sum()
    for pair, index2 in tqdm(cntv2.vocabulary_.items()):
        freq12 = cnt_lenta_2[0, index2]
        if freq12 < thr:
            continue
        words = pair.split(' ')
        freq1 = cnt_lenta_1[0, cntv1.vocabulary_[words[0]]]
        freq2 = cnt_lenta_1[0, cntv1.vocabulary_[words[1]]]
        mis[pair] = freq12 / (freq1 * freq2)
        t_scores[pair] = (freq12 - (freq1 * freq2) / corp_len) / np.sqrt(freq12)
    return mis, t_scores

# %%
mis, t_scores = calc_MI_tscore(cnt_lenta_1, cnt_lenta_2, cntv1, cntv2, 10)
# Out:
# 100%|█████████████████████████████████| 139114/139114 [02:09<00:00, 1076.92it/s]

# %%
sorted(mis.items(), key=lambda x: x[1], reverse=True)[:100]
# Out:
# [('январярусский смертьзакать', 0.1),
#  ('январясадизм какой-тобдсм-маска', 0.1),
#  ('февралязолоть стволыонить', 0.1),
#  ('упалокто ронять', 0.08333333333333333),
#  ('демьян кудрявцев', 0.08333333333333333),
#  ('возрождать сверхзвуковой', 0.07692307692307693),
#  ('рен тв', 0.07692307692307693),
#  ('сверхзвуковой ракетоносец', 0.06993006993006994),
#  ('рекс тиллерсон', 0.06666666666666667),
#  ('раюдин юсуфов', 0.06666666666666667),
#  ('шахабас шахов', 0.06666666666666667),
#  ('исаев раюдин', 0.0625),
#  ('какой-тобдсм-маска суровый', 0.058823529411764705),
#  ('февралякаждый своероссия', 0.058823529411764705),
#  ('оливковый ветвь', 0.05803571428571429),
#  ('суровый госпожа', 0.053475935828877004),
#  ('алина загитов', 0.04807692307692308),
#  ('шамиль исаев', 0.046875),
#  ('саудовский аравия', 0.045454545454545456),
#  ('хайат тахрир', 0.043478260869565216),
#  ('настя рыбка', 0.04292929292929293),
#  ('тахрир аш-ша', 0.03985507246376811),
#  ('джабхата ан-нуср', 0.03764705882352941),
#  ('переносный зенитно-ракетный', 0.03741496598639456),
#  ('ксения собчак', 0.03492063492063492),
#  ('автомат калашников', 0.034324942791762014),
#  ('харви вайнштейн', 0.03333333333333333),
#  ('стволыонить держать', 0.03333333333333333),
#  ('подорвать граната', 0.03213610586011342),
#  ('присвоить звание', 0.03205128205128205),
#  ('абдусамад гамидов', 0.031862745098039214),
#  ('джейша ана-наср', 0.030303030303030304),
#  ('катапультироваться приземлиться', 0.03021978021978022),
#  ('прогресс мс', 0.028985507246376812),
#  ('святой валентина', 0.02849002849002849),
#  ('латинский америка', 0.027548209366391185),
#  ('своероссия просить', 0.02631578947368421),
#  ('анастасия брызгалов', 0.025793650793650792),
#  ('сельский хозяйство', 0.02546296296296296),
#  ('программный обеспечение', 0.025252525252525252),
#  ('орск оренбургский', 0.025252525252525252),
#  ('точка зрение', 0.024444444444444446),
#  ('антон шипулина', 0.022569444444444444),
#  ('миланский мода', 0.022172949002217297),
#  ('сей пора', 0.02127659574468085),
#  ('граната плен', 0.020933977455716585),
#  ('саратовский авиалиния', 0.020370370370370372),
#  ('илона маск', 0.019585253456221197),
#  ('учебный заведение', 0.019308943089430895),
#  ('околоземный орбита', 0.019),
#  ('исполнять обязанность', 0.018790849673202614),
#  ('верховный рада', 0.018282988871224166),
#  ('полезный нагрузка', 0.01806451612903226),
#  ('игорный зона', 0.017361111111111112),
#  ('колония строгий', 0.016835016835016835),
#  ('летательный аппарат', 0.01636904761904762),
#  ('февралядвижение разбиться', 0.016129032258064516),
#  ('филип катапультироваться', 0.01600985221674877),
#  ('виктор янукович', 0.01594896331738437),
#  ('нижний бельё', 0.015873015873015872),
#  ('лишение свобода', 0.015625),
#  ('телефонный разговор', 0.015432098765432098),
#  ('григорий родченков', 0.015),
#  ('краснодарский край', 0.014545454545454545),
#  ('аэропорт домодедово', 0.014444444444444444),
#  ('дагестан абдусамад', 0.013958125623130608),
#  ('наслать мишень', 0.013888888888888888),
#  ('ближний восток', 0.013736263736263736),
#  ('низкий околоземный', 0.013043478260869565),
#  ('детский сад', 0.012987012987012988),
#  ('набирать популярность', 0.012865497076023392),
#  ('мода встать', 0.012836970474967908),
#  ('народный самооборона', 0.012670565302144249),
#  ('ким чен', 0.012345679012345678),
#  ('илона маска', 0.011904761904761904),
#  ('человеческий фактор', 0.011904761904761904),
#  ('звание герой', 0.01171875),
#  ('резервный фонд', 0.0117096018735363),
#  ('зенитно-ракетный комплекс', 0.011627906976744186),
#  ('всемирный боксёрский', 0.011494252873563218),
#  ('гонка преследование', 0.011441647597254004),
#  ('подмосковьен борт', 0.011235955056179775),
#  ('удовлетворить апелляция', 0.011224489795918367),
#  ('пётр порошенко', 0.011086474501108648),
#  ('конкурс управленец', 0.010964912280701754),
#  ('населить пункт', 0.01094027202838557),
#  ('пожизненный дисквалификация', 0.0107421875),
#  ('дагестан десятилетие', 0.01059322033898305),
#  ('строгий режим', 0.01053639846743295),
#  ('палата парламент', 0.01048951048951049),
#  ('потерпеть крушение', 0.01008827238335435),
#  ('сергей шойгу', 0.009900990099009901),
#  ('семья демьян', 0.009708737864077669),
#  ('олег дерипаск', 0.00962962962962963),
#  ('третий рейх', 0.009615384615384616),
#  ('кремлёвский доклад', 0.009511993382961124),
#  ('спортивный арбитражный', 0.009436881188118812),
#  ('январядвойный удар', 0.009259259259259259),
#  ('дональд трамп', 0.00911592707258342),
#  ('погодный условие', 0.008928571428571428)]

# %%
sorted(t_scores.items(), key=lambda x: x[1], reverse=True)[:100]
# Out:
# [('материал тема', 29.310248678044985),
#  ('олимпийский игра', 12.609762051359896),
#  ('российский спортсмен', 11.305263157174075),
#  ('владимир путин', 10.890176441955774),
#  ('тот число', 10.86274528541703),
#  ('президент россия', 10.435286936796796),
#  ('олимпийский комитет', 10.434333194318143),
#  ('риа новость', 10.380572046853729),
#  ('игра пхенчхан', 10.196138421758771),
#  ('тема декабрь', 10.0570068093562),
#  ('уголовный дело', 9.975051441649006),
#  ('миллион доллар', 9.836360208198426),
#  ('который быть', 9.82751758837726),
#  ('февраль сообщать', 9.709321092299627),
#  ('миллион рубль', 9.692408505407585),
#  ('миллиард доллар', 9.554508232737279),
#  ('среда февраль', 9.439329953051642),
#  ('прошлое год', 9.413128883623688),
#  ('международный олимпийский', 9.274609909692773),
#  ('декабрь год', 9.260125332482954),
#  ('тема январь', 9.04079617288343),
#  ('понедельник февраль', 8.978137866035349),
#  ('настоящий время', 8.93791995000938),
#  ('вторник февраль', 8.816872246718969),
#  ('новость канал', 8.62563690007607),
#  ('канал лента', 8.608645919611806),
#  ('пятница февраль', 8.528632945623857),
#  ('запретить россия', 8.466932775976195),
#  ('обратить внимание', 8.360307683954282),
#  ('важный новость', 8.231018005560045),
#  ('день подписываться', 8.22869321993411),
#  ('комитет мокнуть', 8.216573968100406),
#  ('лента день', 8.163698784961499),
#  ('четверг февраль', 8.057667368608291),
#  ('такой образ', 8.032503057784618),
#  ('арбитражный суд', 7.985385953479303),
#  ('спортивный арбитражный', 7.8060028258192355),
#  ('тысяча рубль', 7.7835389948975084),
#  ('должный быть', 7.753455207043895),
#  ('россия владимир', 7.6918918776295815),
#  ('южный корея', 7.608722698110232),
#  ('тема ноябрь', 7.582596027024138),
#  ('принять участие', 7.575172621305326),
#  ('глава государство', 7.565940522008606),
#  ('сборная россия', 7.54967486214334),
#  ('январь год', 7.544998275668343),
#  ('президент сша', 7.542508919183307),
#  ('исламский государство', 7.540190029635129),
#  ('следственный комитет', 7.536646271285297),
#  ('молодой человек', 7.5032096130999575),
#  ('корреспондент лента', 7.468606429381388),
#  ('сообщаться сайт', 7.432395103176798),
#  ('член экипаж', 7.406650139024797),
#  ('прим лента', 7.403830608706769),
#  ('олимпиада пхенчхан', 7.3667235139936835),
#  ('дональд трамп', 7.276011930429745),
#  ('статья ук', 7.275477659220786),
#  ('тема октябрь', 7.265416433445308),
#  ('правоохранительный орган', 7.20604885047284),
#  ('возбудить уголовный', 7.204164564524486),
#  ('миллиард рубль', 7.099104088012174),
#  ('атлет россия', 7.09533566559348),
#  ('антидопинговый правило', 7.060037467117618),
#  ('социальный сеть', 6.986734761946301),
#  ('февраль год', 6.87560661624769),
#  ('сообщать издание', 6.812474572394729),
#  ('нарушение антидопинговый', 6.770376109185544),
#  ('тысяча человек', 6.764153509064506),
#  ('тысяча доллар', 6.733142258647016),
#  ('провинция идлиб', 6.7026382691443676),
#  ('саратовский авиалиния', 6.631578652030508),
#  ('ноябрь год', 6.571710330951271),
#  ('инцидент произойти', 6.537820710568295),
#  ('март год', 6.510515027633642),
#  ('конец год', 6.509597522009133),
#  ('слово приводить', 6.494394680526331),
#  ('сентябрь год', 6.425990217372896),
#  ('февраль сообщаться', 6.424576259635526),
#  ('год сообщаться', 6.421227019859005),
#  ('тема июль', 6.409198405987487),
#  ('октябрь год', 6.396643758847175),
#  ('конец январь', 6.39350607018821),
#  ('свой очередь', 6.36181709842726),
#  ('олимпийский атлет', 6.359798421869784),
#  ('воскресение февраль', 6.340536448969632),
#  ('прошлый год', 6.338064673296284),
#  ('раменское район', 6.317869915417913),
#  ('штурмовик су', 6.23811074830632),
#  ('весь мир', 6.201608776673889),
#  ('государство иго', 6.148485785783427),
#  ('комитет россия', 6.1381687320184755),
#  ('сша дональд', 6.137226571482317),
#  ('продлиться февраль', 6.107676752727687),
#  ('населить пункт', 6.079909520640702),
#  ('сообщаться пресс-релиз', 6.067031328614781),
#  ('говориться сообщение', 6.0625670686775885),
#  ('игра сочи', 6.048070877679722),
#  ('террористический группировка', 5.993103483664391),
#  ('пассажир член', 5.987568481962497),
#  ('речь идти', 5.911791584008501)]

# %% [markdown]
# Несколько странные слова в топе в самом деле есть в тексте. Просто надо было при морфологическом анализе посмотреть, что это предсказанные слова, а не словарные.
#
# Вообще, появление этих слов связано с тем, что MI поощряет появление редких слов. Например, если есть два слова, встретившихся вместе 1 раз, причем каждое слово встретилось только один раз (то есть они встретились только вместе), то MI = 1 / 1 * 1 = 1, то есть максимальному значению. Если есть два слова, встречающиеся только вместе, но 100 раз, MI = 100 / 100 * 100 = 0.01.
#
# Посмотрим какие словосочетания встречаются больше 100 раз и какие у них получаются значения метрик.

# %%
mis_100, t_scores_100 = calc_MI_tscore(cnt_lenta_1, cnt_lenta_2, cntv1, cntv2, 100)
# Out:
# 100%|█████████████████████████████████| 138539/138539 [01:34<00:00, 1458.48it/s]

# %%
sorted(mis_100.items(), key=lambda x: x[1], reverse=True)[:100]
# Out:
# [('риа новость', 0.004545071963639425),
#  ('владимир путин', 0.0030199213297804847),
#  ('уголовный дело', 0.0020567667626491155),
#  ('игра пхенчхан', 0.0010347988055465216),
#  ('олимпийский комитет', 0.00100116499199068),
#  ('материал тема', 0.000997279311739402),
#  ('олимпийский игра', 0.0008260985571496008),
#  ('тот число', 0.000612948537862342),
#  ('российский спортсмен', 0.00041872834439287586),
#  ('тема декабрь', 0.00037104692316474483),
#  ('президент россия', 0.00016495267564615944),
#  ('февраль сообщать', 0.00010707519973643028),
#  ('который быть', 3.4707271564828227e-05)]

# %%
sorted(t_scores_100.items(), key=lambda x: x[1], reverse=True)[:100]
# Out:
# [('материал тема', 29.310248678044985),
#  ('олимпийский игра', 12.609762051359896),
#  ('российский спортсмен', 11.305263157174075),
#  ('владимир путин', 10.890176441955774),
#  ('тот число', 10.86274528541703),
#  ('президент россия', 10.435286936796796),
#  ('олимпийский комитет', 10.434333194318143),
#  ('риа новость', 10.380572046853729),
#  ('игра пхенчхан', 10.196138421758771),
#  ('тема декабрь', 10.0570068093562),
#  ('уголовный дело', 9.975051441649006),
#  ('который быть', 9.82751758837726),
#  ('февраль сообщать', 9.709321092299627)]

# %% [markdown]
# Попробуем теперь избавиться от "странных" слов, получившихся из-за их склейки. PyMorphy2 помечает их, помещая данные о том, как проводился разбор в свойство `methods_stack`. Если слово было разобрано по словарю, будет использован `DictionaryAnalyzer`. Одно из многих значений для предсказанных слов - `FakeDictionary`.

# %%
[type(x[0]) for x in morph.parse('русский')[0].methods_stack]
# Out:
# [pymorphy2.units.by_lookup.DictionaryAnalyzer]

# %%
[type(x[0]) for x in morph.parse('январярусский')[0].methods_stack]
# Out:
# [pymorphy2.units.by_analogy.KnownSuffixAnalyzer.FakeDictionary,
#  pymorphy2.units.by_analogy.KnownSuffixAnalyzer]

# %%
pymorphy2.units.by_analogy.KnownSuffixAnalyzer.FakeDictionary in [type(x[0]) for x in morph.parse('январярусский')[0].methods_stack]
# Out:
# True

# %% [markdown]
# Перепишем функцию морфологического анализа так, чтобы она отсеивала несловарные слова (или хотя бы их часть).

# %%
imp_POS = ['ADJF', 'ADJS', 'NOUN', 'VERB', 'PRTF', 'PRTS', 'GRND', 'PREP']


def normalizePymorphy2(text):
    tokens = re.findall('[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+', text)
    words = []
    for t in tokens:
        pv = morph.parse(t)
        # Здесь мы проверяем, что слово было предсказано словарем.
        if str(pv[0].tag.POS) in imp_POS and \
          pymorphy2.units.by_lookup.DictionaryAnalyzer in [type(x[0]) for x in pv[0].methods_stack]:
            words.append(pv[0].normal_form)
            
    return words

# %%
lenta_news = [' '.join(normalizePymorphy2(news)) for news in tqdm(lenta_news.split(' '))]
habr_news = [' '.join(normalizePymorphy2(news)) for news in tqdm(habr_news).split(' ')]
# Out:
# 100%|███████████████████████████████████████| 1708/1708 [00:39<00:00, 42.82it/s]
# 100%|█████████████████████████████████████████| 708/708 [00:19<00:00, 36.13it/s]

# %%
cntv12 = CountVectorizer(token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                        ngram_range=(1, 1))
cntv22 = CountVectorizer(token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                        ngram_range=(2, 2))

# %%
cnt_lenta_12 = cntv12.fit_transform(['\n'.join(lenta_news)])
cnt_lenta_22 = cntv22.fit_transform(['\n'.join(lenta_news)])

# %%
mis, t_scores = calc_MI_tscore(cnt_lenta_12, cnt_lenta_22, cntv12, cntv22, 10)
# Out:
# 100%|█████████████████████████████████| 135212/135212 [01:30<00:00, 1487.83it/s]

# %%
sorted(mis.items(), key=lambda x: x[1], reverse=True)[:100]
# Out:
# [('демьян кудрявцев', 0.08333333333333333),
#  ('возрождать сверхзвуковой', 0.07692307692307693),
#  ('рен тв', 0.07692307692307693),
#  ('сверхзвуковой ракетоносец', 0.06993006993006994),
#  ('раюдин юсуфов', 0.06666666666666667),
#  ('шахабас шахов', 0.06666666666666667),
#  ('исаев раюдин', 0.0625),
#  ('оливковый ветвь', 0.05803571428571429),
#  ('суровый госпожа', 0.053475935828877004),
#  ('алина загитов', 0.04807692307692308),
#  ('шамиль исаев', 0.046875),
#  ('саудовский аравия', 0.045454545454545456),
#  ('настя рыбка', 0.04292929292929293),
#  ('переносный зенитно-ракетный', 0.03741496598639456),
#  ('ксения собчак', 0.03492063492063492),
#  ('автомат калашников', 0.034324942791762014),
#  ('харви вайнштейн', 0.03333333333333333),
#  ('подорвать граната', 0.03213610586011342),
#  ('присвоить звание', 0.03205128205128205),
#  ('абдусамад гамидов', 0.031862745098039214),
#  ('катапультироваться приземлиться', 0.03021978021978022),
#  ('прогресс мс', 0.028985507246376812),
#  ('святой валентина', 0.02849002849002849),
#  ('латинский америка', 0.027548209366391185),
#  ('своероссия просить', 0.02631578947368421),
#  ('анастасия брызгалов', 0.025793650793650792),
#  ('сельский хозяйство', 0.02546296296296296),
#  ('программный обеспечение', 0.025252525252525252),
#  ('орск оренбургский', 0.025252525252525252),
#  ('точка зрение', 0.024444444444444446),
#  ('антон шипулина', 0.022569444444444444),
#  ('миланский мода', 0.022172949002217297),
#  ('сей пора', 0.02127659574468085),
#  ('граната плен', 0.020933977455716585),
#  ('саратовский авиалиния', 0.020370370370370372),
#  ('илона маск', 0.019585253456221197),
#  ('учебный заведение', 0.019308943089430895),
#  ('околоземный орбита', 0.019),
#  ('исполнять обязанность', 0.018790849673202614),
#  ('верховный рада', 0.018282988871224166),
#  ('полезный нагрузка', 0.01806451612903226),
#  ('игорный зона', 0.017361111111111112),
#  ('колония строгий', 0.016835016835016835),
#  ('летательный аппарат', 0.01636904761904762),
#  ('филип катапультироваться', 0.01600985221674877),
#  ('виктор янукович', 0.01594896331738437),
#  ('нижний бельё', 0.015873015873015872),
#  ('лишение свобода', 0.015625),
#  ('телефонный разговор', 0.015432098765432098),
#  ('григорий родченков', 0.015),
#  ('краснодарский край', 0.014545454545454545),
#  ('аэропорт домодедово', 0.014444444444444444),
#  ('дагестан абдусамад', 0.013958125623130608),
#  ('наслать мишень', 0.013888888888888888),
#  ('ближний восток', 0.013736263736263736),
#  ('низкий околоземный', 0.013043478260869565),
#  ('детский сад', 0.012987012987012988),
#  ('набирать популярность', 0.012865497076023392),
#  ('мода встать', 0.012836970474967908),
#  ('народный самооборона', 0.012670565302144249),
#  ('ким чен', 0.012345679012345678),
#  ('илона маска', 0.011904761904761904),
#  ('человеческий фактор', 0.011904761904761904),
#  ('звание герой', 0.01171875),
#  ('резервный фонд', 0.0117096018735363),
#  ('зенитно-ракетный комплекс', 0.011627906976744186),
#  ('всемирный боксёрский', 0.011494252873563218),
#  ('гонка преследование', 0.011441647597254004),
#  ('удовлетворить апелляция', 0.011224489795918367),
#  ('пётр порошенко', 0.011086474501108648),
#  ('конкурс управленец', 0.010964912280701754),
#  ('населить пункт', 0.01094027202838557),
#  ('пожизненный дисквалификация', 0.0107421875),
#  ('дагестан десятилетие', 0.01059322033898305),
#  ('строгий режим', 0.01053639846743295),
#  ('палата парламент', 0.01048951048951049),
#  ('потерпеть крушение', 0.01008827238335435),
#  ('сергей шойгу', 0.009900990099009901),
#  ('семья демьян', 0.009708737864077669),
#  ('олег дерипаск', 0.00962962962962963),
#  ('третий рейх', 0.009615384615384616),
#  ('кремлёвский доклад', 0.009511993382961124),
#  ('спортивный арбитражный', 0.009436881188118812),
#  ('дональд трамп', 0.00911592707258342),
#  ('погодный условие', 0.008928571428571428),
#  ('правительственный войско', 0.008633633633633633),
#  ('тонна груз', 0.008597883597883597),
#  ('павел грудинин', 0.008484848484848486),
#  ('тюремный заключение', 0.00847457627118644),
#  ('информатор всемирный', 0.008301404853128991),
#  ('роман филип', 0.008234688625836336),
#  ('майор роман', 0.00808457711442786),
#  ('статья ук', 0.008064516129032258),
#  ('роман филиповый', 0.007995735607675906),
#  ('воздушный судный', 0.007936507936507936),
#  ('командный соревнование', 0.007901668129938543),
#  ('звёздный война', 0.007727272727272728),
#  ('отряд народный', 0.007625272331154684),
#  ('пенсионный возраст', 0.00739247311827957),
#  ('мобильный приложение', 0.007331378299120235)]

# %%
sorted(t_scores.items(), key=lambda x: x[1], reverse=True)[:100]
# Out:
# [('по тема', 29.025277358715545),
#  ('материал по', 28.961915573112304),
#  ('один из', 20.637085675507265),
#  ('по слово', 19.895021645148802),
#  ('в год', 18.621192226259957),
#  ('о сообщать', 18.028953646724318),
#  ('в время', 15.10094696920619),
#  ('в пхенчхан', 13.16388698643111),
#  ('по данные', 12.82436070355068),
#  ('олимпийский игра', 12.622321641210553),
#  ('на сайт', 12.565720730570636),
#  ('игра в', 11.605566514111159),
#  ('в тот', 11.549181388086014),
#  ('российский спортсмен', 11.37166381854365),
#  ('в частность', 11.312918715712376),
#  ('в россия', 11.014641611104727),
#  ('владимир путин', 10.893130181749246),
#  ('тот число', 10.877359012498646),
#  ('ссылка на', 10.849066547151036),
#  ('в результат', 10.834003168804951),
#  ('участие в', 10.824299030417833),
#  ('с ссылка', 10.595874217708191),
#  ('президент россия', 10.48867743985809),
#  ('олимпийский комитет', 10.442899332391226),
#  ('в конец', 10.414717291660702),
#  ('риа новость', 10.382441719165735),
#  ('тема декабрь', 10.079480904640327),
#  ('который быть', 10.050367530677521),
#  ('кроме тот', 10.049334040247674),
#  ('на олимпиада', 9.98015420032425),
#  ('уголовный дело', 9.979027102573948),
#  ('миллион доллар', 9.846421000859387),
#  ('в свой', 9.810098807645018),
#  ('в отношение', 9.78256017179823),
#  ('говориться в', 9.765277216523858),
#  ('по мнение', 9.711522822589789),
#  ('миллион рубль', 9.701075124678173),
#  ('февраль сообщать', 9.632980092158208),
#  ('миллиард доллар', 9.56042901339604),
#  ('среда февраль', 9.455275276258632),
#  ('прошлое год', 9.433249460825355),
#  ('в ход', 9.42212262675484),
#  ('о тот', 9.339335288216853),
#  ('после тот', 9.32452034056512),
#  ('декабрь год', 9.32124177209428),
#  ('международный олимпийский', 9.283018901446551),
#  ('тема январь', 9.194945604208874),
#  ('о сообщаться', 9.179506043837836),
#  ('в сирия', 9.161863035302197),
#  ('в рамка', 9.026618363303388),
#  ('понедельник февраль', 8.990447553710835),
#  ('олимпиада в', 8.973170511840456),
#  ('новость в', 8.955258751366367),
#  ('настоящий время', 8.947812675091676),
#  ('в декабрь', 8.92929377066044),
#  ('с помощь', 8.875025599714807),
#  ('связь с', 8.842950348027479),
#  ('в среда', 8.840039065311661),
#  ('вторник февраль', 8.828237743784316),
#  ('несмотря на', 8.826132409220403),
#  ('в понедельник', 8.789815103080636),
#  ('на процент', 8.635203912568473),
#  ('канал лента', 8.616869896972759),
#  ('в вторник', 8.56425278211274),
#  ('пятница февраль', 8.54037613649729),
#  ('в сочи', 8.529718379365676),
#  ('на игра', 8.528143843866918),
#  ('в сеть', 8.45411357851432),
#  ('из россия', 8.435139701777343),
#  ('в течение', 8.388074809948394),
#  ('находиться в', 8.377472494247082),
#  ('в настоящий', 8.372495329406936),
#  ('обратить внимание', 8.361310434076485),
#  ('в состав', 8.304423391283517),
#  ('до год', 8.300910633536612),
#  ('на территория', 8.267673555105269),
#  ('борьба с', 8.238555511868432),
#  ('важный новость', 8.233439115120943),
#  ('день подписываться', 8.23148479416242),
#  ('комитет мокнуть', 8.221296797645232),
#  ('лента день', 8.176847504152809),
#  ('в январь', 8.14122287854997),
#  ('в пятница', 8.086064187608272),
#  ('четверг февраль', 8.068243880916967),
#  ('в качество', 8.052513651803038),
#  ('такой образ', 8.03724459670425),
#  ('на борт', 8.035371800410585),
#  ('арбитражный суд', 7.987714765144097),
#  ('запретить в', 7.970261054863213),
#  ('рассказать о', 7.950105967884286),
#  ('о сообщить', 7.936102824525929),
#  ('в четверг', 7.9332203844392195),
#  ('с сторона', 7.926128944760431),
#  ('информация о', 7.89566389905715),
#  ('сообщаться на', 7.8142230910606205),
#  ('спортивный арбитражный', 7.806679579790712),
#  ('тысяча рубль', 7.797955602965907),
#  ('дело о', 7.778628453594498),
#  ('должный быть', 7.748341358188391),
#  ('россия владимир', 7.720912851123809)]

# %% [markdown]
# Расмотрим теперь еще одну метрику - странность (weirdness). Для ее вычисления требуется рассчитать частоты сочетаний выбранной длинны в тематической коллекции и в еще одной - контрастивной, специально подобранном из другой предметной области. После этого рассчитывается отношение частот в тематическом и контрастивной коллекции. Для того, чтобы не делить на 0, применим сглаживание Лагранжа, то есть прибавим 1 к знаменателю.
#
# Так как термины предметной области будут встречаться чаще в тематической коллекции, то самые большие значения будут у слов, похожих на термины. Верно и обратное, так как термины контрастивной коллекции чаще встречаются в ней, то близкие к 0 значения будут означать термины контрастивной коллеции.

# %%
hcntv1 = CountVectorizer(token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                         ngram_range=(1, 1))
hcntv2 = CountVectorizer(token_pattern="[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+-[а-яёА-ЯЁ]+|[а-яёА-ЯЁ]+", 
                         ngram_range=(2, 2))

# %%
cnt_habr_1 = hcntv1.fit_transform(['\n'.join(habr_news)])
cnt_habr_2 = hcntv2.fit_transform(['\n'.join(habr_news)])

# %%
weir_1 = {}
weir_2 = {}
for word, index in tqdm(hcntv1.vocabulary_.items()):
    if word in cntv1.vocabulary_.keys():
        w = cnt_habr_1[0, index] / (cnt_lenta_1[0, cntv1.vocabulary_[word]] + 1)
    else:
        w = cnt_habr_1[0, index]
    weir_1[word] = w
    
for word, index in tqdm(hcntv2.vocabulary_.items()):
    if word in cntv2.vocabulary_.keys():
        w = cnt_habr_2[0, index] / (cnt_lenta_2[0, cntv2.vocabulary_[word]] + 1)
    else:
        w = cnt_habr_2[0, index]
    weir_2[word] = w
# Out:
# 100%|█████████████████████████████████████| 9698/9698 [00:01<00:00, 8666.68it/s]
# 100%|███████████████████████████████████| 70832/70832 [00:26<00:00, 2703.90it/s]

# %%
sorted(weir_1.items(), key=lambda x: x[1], reverse=True)[:100]
# Out:
# [('шрифт', 162),
#  ('самохвалов', 153),
#  ('граф', 130),
#  ('настройка', 96),
#  ('евтеев', 90),
#  ('плагин', 82),
#  ('браузер', 72),
#  ('её', 68),
#  ('метрика', 64),
#  ('префикс', 57),
#  ('фреймворк', 52),
#  ('интерфейс', 50.5),
#  ('оптимизация', 50),
#  ('бурладянин', 50),
#  ('шаблон', 47),
#  ('скрипт', 46.5),
#  ('стек', 45),
#  ('хабра', 45),
#  ('текстура', 45),
#  ('трафаретный', 45),
#  ('линейный', 44),
#  ('буфер', 43),
#  ('строка', 42.75),
#  ('фича', 42),
#  ('построение', 42),
#  ('переменный', 38.0),
#  ('тестировщик', 37),
#  ('актор', 37),
#  ('автоматизация', 35),
#  ('буква', 34.5),
#  ('вершина', 34.333333333333336),
#  ('нейронный', 33),
#  ('лямбда', 31),
#  ('классификация', 30),
#  ('преобразование', 30),
#  ('иконка', 30),
#  ('уза', 30),
#  ('гб', 29),
#  ('алгоритм', 28.0),
#  ('паттерн', 28),
#  ('датасет', 28),
#  ('лог', 27),
#  ('файл', 26.416666666666668),
#  ('массив', 24.0),
#  ('спецификация', 24),
#  ('биткойна', 24),
#  ('трекер', 23),
#  ('антиква', 23),
#  ('стейкхолдер', 23),
#  ('репозиторий', 22.0),
#  ('кэш', 22),
#  ('лоадер', 22),
#  ('компилятор', 21),
#  ('отрисовка', 21),
#  ('диаграмма', 21),
#  ('триггер', 21),
#  ('ферзь', 21),
#  ('сервер', 20.88888888888889),
#  ('переводчик-фрилансер', 20),
#  ('логика', 20.0),
#  ('облачный', 20),
#  ('хост', 20),
#  ('сарказм', 20),
#  ('рендеринг', 20),
#  ('баг', 19.5),
#  ('регрессия', 19.5),
#  ('компиляция', 19),
#  ('кат', 19),
#  ('конфига', 19),
#  ('п', 19),
#  ('синтаксис', 19),
#  ('подсказка', 19),
#  ('итерация', 19),
#  ('майлстоун', 19),
#  ('макрос', 19),
#  ('ядро', 18.5),
#  ('машинный', 18.333333333333332),
#  ('подход', 18.285714285714285),
#  ('корневой', 18),
#  ('засечка', 18),
#  ('докладчик', 17),
#  ('утилит', 17),
#  ('битый', 17.0),
#  ('читаться', 17),
#  ('плейбук', 17),
#  ('гротеск', 17),
#  ('ассет', 17),
#  ('таблица', 16.333333333333332),
#  ('локальный', 16.25),
#  ('отображение', 16),
#  ('идентификатор', 16),
#  ('ос', 16),
#  ('директория', 16),
#  ('контроллер', 16),
#  ('константа', 16),
#  ('движок', 16),
#  ('содержимое', 15.333333333333334),
#  ('функция', 15.125),
#  ('текстовый', 15),
#  ('обученный', 15)]

# %%
sorted(weir_2.items(), key=lambda x: x[1], reverse=True)[-100:]
# Out:
# [('год который', 0.1111111111111111),
#  ('настоящий момент', 0.1111111111111111),
#  ('мужчина женщина', 0.1111111111111111),
#  ('деньга быть', 0.1111111111111111),
#  ('быть произвести', 0.1111111111111111),
#  ('год время', 0.1111111111111111),
#  ('компания представить', 0.1111111111111111),
#  ('общественный мнение', 0.1111111111111111),
#  ('штраф размер', 0.1111111111111111),
#  ('европейский союз', 0.1111111111111111),
#  ('экономический рост', 0.1111111111111111),
#  ('который проводить', 0.1111111111111111),
#  ('занять первый', 0.1111111111111111),
#  ('миллион человек', 0.1111111111111111),
#  ('начаться год', 0.1111111111111111),
#  ('финальный этап', 0.1111111111111111),
#  ('общий объём', 0.1111111111111111),
#  ('год быть', 0.10666666666666667),
#  ('конец год', 0.10416666666666667),
#  ('наш страна', 0.1),
#  ('год этот', 0.1),
#  ('стать один', 0.1),
#  ('который входить', 0.1),
#  ('быть зафиксировать', 0.1),
#  ('быть выделить', 0.1),
#  ('президент рф', 0.1),
#  ('итог год', 0.1),
#  ('который заниматься', 0.09090909090909091),
#  ('первый мир', 0.09090909090909091),
#  ('председатель правление', 0.09090909090909091),
#  ('представитель компания', 0.09090909090909091),
#  ('быть место', 0.09090909090909091),
#  ('человек получить', 0.09090909090909091),
#  ('стартовать февраль', 0.09090909090909091),
#  ('военный конфликт', 0.09090909090909091),
#  ('человеческий фактор', 0.09090909090909091),
#  ('ближний восток', 0.09090909090909091),
#  ('малый мера', 0.09090909090909091),
#  ('рассказать свой', 0.09090909090909091),
#  ('течение месяц', 0.09090909090909091),
#  ('тот год', 0.09090909090909091),
#  ('сентябрь год', 0.08888888888888889),
#  ('принять участие', 0.0847457627118644),
#  ('ход который', 0.08333333333333333),
#  ('один главный', 0.08333333333333333),
#  ('свой жизнь', 0.08333333333333333),
#  ('главное управление', 0.08333333333333333),
#  ('быть заметить', 0.08333333333333333),
#  ('сельский хозяйство', 0.08333333333333333),
#  ('илона маска', 0.08333333333333333),
#  ('этот день', 0.08333333333333333),
#  ('один пользователь', 0.08333333333333333),
#  ('российский компания', 0.08),
#  ('ноябрь го', 0.07692307692307693),
#  ('течение год', 0.07692307692307693),
#  ('человек год', 0.07692307692307693),
#  ('результат исследование', 0.07692307692307693),
#  ('оккупировать территория', 0.07692307692307693),
#  ('быть провести', 0.07692307692307693),
#  ('новый список', 0.07692307692307693),
#  ('второе место', 0.07142857142857142),
#  ('орган власть', 0.07142857142857142),
#  ('минута секунда', 0.07142857142857142),
#  ('январь год', 0.07042253521126761),
#  ('прошлый год', 0.06976744186046512),
#  ('московский область', 0.06666666666666667),
#  ('полезный нагрузка', 0.06666666666666667),
#  ('составлять тысяча', 0.06666666666666667),
#  ('американский компания', 0.06666666666666667),
#  ('прошлый неделя', 0.06666666666666667),
#  ('принимать участие', 0.06666666666666667),
#  ('последний раз', 0.06666666666666667),
#  ('лицо часть', 0.0625),
#  ('составить миллион', 0.0625),
#  ('миллион евро', 0.0625),
#  ('тысяча доллар', 0.0625),
#  ('настоящий время', 0.06097560975609756),
#  ('миллион доллар', 0.06060606060606061),
#  ('генеральный директор', 0.06060606060606061),
#  ('россия сергей', 0.058823529411764705),
#  ('право человек', 0.058823529411764705),
#  ('занимать должность', 0.058823529411764705),
#  ('чемпион мир', 0.05555555555555555),
#  ('россия быть', 0.05555555555555555),
#  ('близкий время', 0.05),
#  ('быть убить', 0.05),
#  ('учебный заведение', 0.05),
#  ('российский федерация', 0.05),
#  ('первый ступень', 0.047619047619047616),
#  ('октябрь год', 0.044444444444444446),
#  ('нарушение правило', 0.041666666666666664),
#  ('ноябрь год', 0.041666666666666664),
#  ('тысяча человек', 0.04),
#  ('быть год', 0.03333333333333333),
#  ('быть сбить', 0.03225806451612903),
#  ('часть статья', 0.029411764705882353),
#  ('начало год', 0.029411764705882353),
#  ('март год', 0.021739130434782608),
#  ('февраль год', 0.012658227848101266),
#  ('миллиард доллар', 0.010752688172043012)]
